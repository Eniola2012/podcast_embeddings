# %% [markdown]
# # test api

# %%
import pandas as pd #all functions need to be pre-pended with 'pd.' e.g. the DataFrame function must be written as 'pd.DataFrame'
import numpy as np
from openai import OpenAI
import tiktoken
import time
import os 
import re
import json
import openai

from helper_file import chunk_text_with_overlap, RateLimiter, get_model_response, find_overlap, merge_chunks

enc = tiktoken.encoding_for_model('gpt-3.5-turbo')


data_path = "./data"

# %%
podcast_files = os.listdir(os.path.join(data_path,'raw_podcasts'))

# %%
#open_file = 
file_dict = []

for open_file in podcast_files:

    open_file_path = os.path.join(data_path,'raw_podcasts', open_file)

    with open(open_file_path, 'r', encoding='utf-8', errors='replace')as file:
        # Read the file and split into a list at each line break
        lines = file.read().replace("\n", "")
        lines = re.sub(r"\d+:\d+", " ", lines)

        tokens = len(enc.encode(lines))

        file_dict.append({'file':open_file, 'tokens':tokens, 'unknown_chars': lines.count('\uFFFD')})


df = pd.DataFrame(file_dict)

# %%
df
# Out:
#                                                  file  tokens  unknown_chars
# 0            swn_jul2021_food_taxes_and_subsidies.txt   14855              0
# 1                cv_mar2023_equitable_food_policy.txt   16783              0
# 2           jc_oct2021_agricultural_inputs_sector.txt    9043              0
# 3                    cr_may2023_food_system_silos.txt   15073              1
# 4                   cc_jan2019_brexit_and_farming.txt   12925              0
# 5                            ch_jun2021_fisheries.txt   12474              0
# 6        ab_and_jv_oct2023_mapping_sustainability.txt   10258              0
# 7         rm_jul2017_nutrition_security_in_brazil.txt   13932              0
# 8                    af_nov2017_hunger_in_america.txt    9598              0
# 9              aw_and_gh_dec2018_global_nutrition.txt   22605              1
# 10                             at_mar2021_uk_food.txt   15331              1
# 11          sht_jun2023_transforming_food_systems.txt   11664              2
# 12              sh_dec2020_food_policies_in_media.txt   13867              0
# 13                         bw_sep2018_food_policy.txt   15541              0
# 14                       jr_jul2020_world_obesity.txt   13235              1
# 15          jf_sep2021_human_and_planetary_health.txt   14676              0
# 16                  sms_jan2023_corporate_capture.txt   12240              2
# 17                    am_may2021_changing_climate.txt   15754              0
# 18                        mh_mar2019_city_regions.txt   17766              0
# 19                     eb_sep2023_past_approaches.txt   11347              0
# 20          panel_dec2017_motivations_for_cooking.txt   19732              4
# 21                         fw_jan2022_beef_farmer.txt   15544              1
# 22                  ak_feb2021_united_food_summit.txt   15889              0
# 23                               kb_may2022_bread.txt   15424              0
# 24            nk_feb2022_feminist_and_food_policy.txt    7938              1
# 25             jd_jun2022_power_and_participation.txt   15524              0
# 26                      ka_may2020_emergency_food.txt   13791              1
# 27                            kb_sep2022_big_data.txt   15211              1
# 28                              fs_feb2020_brexit.txt   12205              1
# 29  bd_jun2019_system_resilience_in_policy_making.txt   15023              0
# 30                      sb_nov2023_climate_change.txt   12355              1
# 31                       mn_mar2022_food_politics.txt   15011              0
# 32                        lc_nov2022_british_diet.txt   14521              1
# 33  bs_and_amt_oct2017_global_obesity_and_undernut...   17036              0
# 34                       cm_oct2020_big_livestock.txt   16048              0
# 35                   md_sep2020_complex_realities.txt   13799              0
# 36                  ts_apr2021_planning_in_cities.txt   15928              0
# 37         pfs_dec2021_food_inequality_in_america.txt   16588              0
# 38                 lh_jun2018_nutrition_in_policy.txt   16047              2
# 39                               jc_mar2018_trust.txt   15283              0
# 40             sp_jul2023_inequalities_and_health.txt   13868              2
# 41  sb_jan2021_leadership_for_sustainable_food_sys...   12228              0
# 42                    ww_oct2018_lived_experience.txt   11895              0
# 43               bb_may2020_sustainable_nutrition.txt   14293              1
# 44                     af_apr2022_food_oppression.txt   13126              0
# 45               tg_and_pf_nov2021_dietary_change.txt   14855              0
# 46          ct_jun2020_food_precarity_and_poverty.txt   12674              1
# 47                  lj_jan2020_food_supply_chains.txt   13252              0

# %%
prompt_template = f"""The below text comes from an automatically transcribed podcast in which an academic interviews 
another academic on their research in food systems. 
Please summarise the please summarise the podcast to a 500 word abstract, which explains the main themes, 
do not mention the reasearchers/academics involved but the content of the research itself.
do not give the title of the podcast
do not say who presents/hosts the podcast
The podcast transcription is surrounded by triple colons ':::'
::: {lines} :::
"""

# %%
rate_limiter = RateLimiter(50000)

# Ensure the output directory exists
output_directory = os.path.join(data_path,"gpt_summary")
os.makedirs(output_directory, exist_ok=True)

chunk_num = 1

for open_file in podcast_files[0:6]:
    # Construct the expected summary filename
    summary_filename = os.path.join(output_directory, os.path.basename(open_file) + "_summary.txt")

    # Check if the summary file already exists
    if os.path.exists(summary_filename):
        print(f"Summary for {os.path.basename(open_file)} already exists. Skipping.")
        continue  # Skip this file and go to the next iteration

    start_time = time.time()  # Start timing

    # Assuming open_file_path is correctly defined based on open_file
    with open(open_file_path, 'r', encoding='utf-8', errors='replace') as file:
        lines = file.read().replace("\n", "")
        lines = re.sub(r"\d+:\d+", " ", lines)

    prompt_text = prompt_template.format(lines=lines)

    # Assuming get_model_response is correctly defined and returns the expected output
    response = get_model_response(prompt_text, 'You are an expert in summarisation of podcasts', 
                                  rate_limiter, engine="gpt-4-turbo-preview").choices[0].message.content
    
    # Save the response to the summary file
    with open(summary_filename, 'w', encoding='utf-8') as summary_file:
        summary_file.write(response)

    end_time = time.time()  # End timing
    chunk_time = end_time - start_time  # Calculate the time taken for this chunk

    print(f"text chunk: {chunk_num}/{len(podcast_files)} complete, time taken {chunk_time:.2f} seconds")
    chunk_num += 1
# Out:
# text chunk: 1/48 complete, time taken 18.75 seconds
# text chunk: 2/48 complete, time taken 17.35 seconds
# text chunk: 3/48 complete, time taken 23.81 seconds
# text chunk: 4/48 complete, time taken 17.20 seconds
# text chunk: 5/48 complete, time taken 12.90 seconds
# text chunk: 6/48 complete, time taken 31.23 seconds

# %%
summary_texts = []

for filename in os.listdir(output_directory):
    # Construct the full path to the file
    file_path = os.path.join(output_directory, filename)
    
    # Check if it's a file and not a directory
    if os.path.isfile(file_path):
        # Open and read the file's contents
        with open(file_path, 'r', encoding='utf-8') as file:
            file_content = file.read()
            summary_texts.append(file_content)


summary_texts
# Out:
ological advancements. She critiques the focus on driving down costs at the expense of quality and sustainability, pointing to the need for a reevaluation of how value and cost are perceived and allocated within the food system.\n\nIn conclusion, the podcast presents a compelling argument for the critical examination of food supply chains as a necessary step towards redesigning more sustainable food systems. By uncovering the hidden practices and financial dynamics that underpin the current system, Jack\'s research offers valuable insights into the challenges and opportunities for achieving meaningful change. The discussion underscores the importance of a holistic understanding of the food system, advocating for a shift in focus towards practices that prioritize sustainability, fairness, and resilience.',
#  "The podcast delves into the critical but often overlooked aspects of food supply chains and their significant impact on the sustainability and redesign of food systems. The discussion centers around the work of Professor Lisa Jack, who brings a unique perspective to the table as a professor of accounting with a focus on the food industry. Her research aims to uncover the hidden practices within food supply chains that, unless understood, hinder our ability to effect meaningful change in the conventional food system.\n\nOne of the main themes explored is the complexity of food supply chains and the narrow margins that characterize the industry. Jack highlights the pervasive issue of waste and inefficiency within these systems, where a significant portion of the money spent by consumers does not reach the producers but is lost to various intermediaries and operational costs. This inefficiency is exemplified by the historical and current margins received by tea producers, which have remained strikingly consistent over centuries, indicating a long-standing structural issue within global food supply chains.\n\nJack also discusses the challenges faced by alternative food systems, which, despite their intentions to create sustainable change, encounter similar obstacles related to overheads, margins, and the inherent difficulties of operating within a tightly constrained economic model. These challenges underscore the need for a deeper understanding and rethinking of how food supply chains are structured and operated.\n\nThe podcast further explores the role of supermarkets and their business models, which have remained fundamentally unchanged since the mid-20th century. Supermarkets operate on thin margins, necessitating high volumes of sales and a variety of strategies to ensure profitability, including charging suppliers for shelf space and promotional efforts. This system puts additional pressure on suppliers and contributes to the perpetuation of narrow margins throughout the supply chain.\n\nAnother critical issue addressed is the environmental and social impact of current food supply chain practices. The discussion touches on the paradox of needing cheap food to accommodate low-wage workers within the food industry itself, highlighting the systemic nature of the problem. Jack suggests that a radical rethinking of the food system might involve questioning the very basis of food as a market commodity and exploring models that prioritize social and environmental sustainability over profit maximization.\n\nIn conclusion, the podcast presents a compelling argument for the need to deeply understand and fundamentally redesign food supply chains. By examining the hidden practices and structural inefficiencies that characterize the current system, Jack's research points towards the possibility of creating a more sustainable, equitable, and efficient food system that benefits all stakeholders, from producers to consumers.",
#  'The podcast delves into the critical importance of understanding food supply chains for the purpose of redesigning food systems. The main theme revolves around the complexities and hidden aspects of food supply chains that significantly impact the sustainability and efficiency of food systems globally. The discussion emphasizes that without a deep understanding of these supply chain practices, efforts to change or improve the food system may fall short.\n\nThe research presented highlights the conventional food system and the learning opportunities it presents for alternative food systems. It is pointed out that the middle segments of the supply chain, often overlooked in research, play a crucial role in the functioning of the entire system. These segments include processing, distribution, and other intermediary steps that connect producers with consumers. The podcast underscores the necessity of bringing these middle segments into focus to achieve a comprehensive understanding of the food supply chain.\n\nOne of the key insights shared is the concept of marginal costing and its implications for pricing and profitability within the food industry. The discussion elaborates on how supermarkets and other large players in the food supply chain manage to maintain profitability through tight control over margins and costs. This includes strategies such as shifting costs down the chain, negotiating prices based on gross margins, and generating income from suppliers through various agreements. The podcast points out the challenges faced by producers and suppliers in dealing with these practices, highlighting the power dynamics and inequalities present in the system.\n\nThe role of technology, transportation, and other overhead costs in shaping the food supply chain is also discussed. It is noted that these costs contribute to the complexity of the system and have a significant impact on the final price of food products. The conversation touches upon the issue of food waste and how it is intertwined with the economic and operational aspects of the food supply chain. The suggestion is made that rethinking the system to avoid waste from the outset could lead to more efficient and sustainable practices.\n\nFurthermore, the podcast explores the potential for alternative food systems and enterprises to address some of the challenges identified. However, it is acknowledged that these alternatives also encounter similar issues related to margins, overheads, and sustainability. The discussion calls for innovative approaches that can free up the system from its current constraints and allow for meaningful change.\n\nIn conclusion, the podcast presents a nuanced examination of food supply chains, emphasizing the need for a deeper understanding and critical analysis to redesign food systems effectively. It calls for a collective effort to address the inherent challenges and explore new models that prioritize sustainability, fairness, and efficiency.']

# %%
import openai

# %%
response = openai.embeddings.create(
    input="Your text here",
    model="text-embedding-3-large",
    dimensions=256
)

embedding =response.data[0].embedding

# %%
def generate_and_save_embeddings(summary_texts, summary_files, embeddings_directory):
    os.makedirs(embeddings_directory, exist_ok=True)
    
    for summary_text, summary_file in zip(summary_texts, summary_files):
        # Construct the filename for the embedding file
        embedding_filename = os.path.splitext(summary_file)[0] + "_embedding.json"
        embedding_file_path = os.path.join(embeddings_directory, embedding_filename)
        
        # Check if the embedding already exists to avoid reprocessing
        if not os.path.exists(embedding_file_path):
            # Generate the embedding
            response = openai.embeddings.create(
                input=summary_text,
                model="text-embedding-3-large",
                dimensions=256
            )
            embedding = response.data[0].embedding
            
            # Save the embedding to a file
            with open(embedding_file_path, 'w', encoding='utf-8') as file:
                json.dump(embedding, file)
                
            print(f"Saved embedding for {summary_file} to {embedding_file_path}")
        else:
            print(f"Embedding for {summary_file} already exists. Skipping.")

# Load the summaries into a list of strings and filenames
def load_summaries_and_filenames(directory):
    summary_texts = []
    summary_files = []
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        if os.path.isfile(file_path):
            with open(file_path, 'r', encoding='utf-8') as file:
                summary_texts.append(file.read())
                summary_files.append(filename)
    return summary_texts, summary_files

# %%
# Directory paths
summary_directory = './data/gpt_summary'
embeddings_directory = './data/gpt_embeddings'

# Load summaries and their filenames
summary_texts, summary_files = load_summaries_and_filenames(summary_directory)

# Generate and save embeddings
generate_and_save_embeddings(summary_texts, summary_files, embeddings_directory)
# Out:
# Saved embedding for jc_oct2021_agricultural_inputs_sector.txt_summary.txt to ./data/gpt_embeddings/jc_oct2021_agricultural_inputs_sector.txt_summary_embedding.json
# Saved embedding for cr_may2023_food_system_silos.txt_summary.txt to ./data/gpt_embeddings/cr_may2023_food_system_silos.txt_summary_embedding.json
# Saved embedding for cc_jan2019_brexit_and_farming.txt_summary.txt to ./data/gpt_embeddings/cc_jan2019_brexit_and_farming.txt_summary_embedding.json
# Saved embedding for cv_mar2023_equitable_food_policy.txt_summary.txt to ./data/gpt_embeddings/cv_mar2023_equitable_food_policy.txt_summary_embedding.json
# Saved embedding for ch_jun2021_fisheries.txt_summary.txt to ./data/gpt_embeddings/ch_jun2021_fisheries.txt_summary_embedding.json
# Saved embedding for swn_jul2021_food_taxes_and_subsidies.txt_summary.txt to ./data/gpt_embeddings/swn_jul2021_food_taxes_and_subsidies.txt_summary_embedding.json
